# %%
import os

# Ruta de la carpeta principal
base_path = r'C:\Users\felip\OneDrive - Universidad Técnica Federico Santa María\Documentos\Brain\Multiple_Brain_Age_Clocks\metricas'

# Recorrer todos los directorios y archivos dentro de base_path
for root, dirs, files in os.walk(base_path):
    for filename in files:
        # Comprobar si el archivo tiene la extensión .xlsx
        if filename.endswith('.xlsx'):
            print(f'Archivo encontrado: {os.path.join(root, filename)}')
# Out:
# Archivo encontrado: C:\Users\felip\OneDrive - Universidad Técnica Federico Santa María\Documentos\Brain\Multiple_Brain_Age_Clocks\metricas\Aperiodic\AD\AR_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx
# Archivo encontrado: C:\Users\felip\OneDrive - Universidad Técnica Federico Santa María\Documentos\Brain\Multiple_Brain_Age_Clocks\metricas\Aperiodic\AD\Bra_USP_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx
# Archivo encontrado: C:\Users\felip\OneDrive - Universidad Técnica Federico Santa María\Documentos\Brain\Multiple_Brain_Age_Clocks\metricas\Aperiodic\AD\CH_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx
# Archivo encontrado: C:\Users\felip\OneDrive - Universidad Técnica Federico Santa María\Documentos\Brain\Multiple_Brain_Age_Clocks\metricas\Aperiodic\AD\COL_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx
# ...

# %%
path_aperiodic = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Aperiodic/'
path_complex = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Complex/'
path_freq = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Freq/'

# %%
path_aperiodic = 'C:/Users/felipe/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Aperiodic/'
path_complex = 'C:/Users/felipe/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Complex/'
path_freq = 'C:/Users/felipe/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Freq/'

# %%
import pandas as pd

# %%
import pandas as pd
# Ruta principal
path_aperiodic = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Aperiodic/'

# Leer archivos y asignar a variables

# Directorio AD
df_AD_arg_aperiodic = pd.read_excel(f"{path_aperiodic}AD/AR_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_bra_aperiodic = pd.read_excel(f"{path_aperiodic}AD/Bra_USP_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_AD_ch_aperiodic = pd.read_excel(f"{path_aperiodic}AD/CH_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_AD_col_aperiodic = pd.read_excel(f"{path_aperiodic}AD/COL_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_tur_aperiodic = pd.read_excel(f"{path_aperiodic}AD/Tur_IUEFM_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")

# Directorio CN
df_CN_aperiodic = pd.read_excel(f"{path_aperiodic}CN/aperiodic_jhosmary_03.xlsx")

# Directorio FTD
df_FTD_arg_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/ARG_FTD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_FTD_ch_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/CH_FTD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_FTD_col_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/Col_processed_SourceTransformation_ODQ_metrics - copia.xlsx")

# Directorio MCI
df_MCI_col_aperiodic = pd.read_excel(f"{path_aperiodic}MCI/Col_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")
df_MCI_tur_aperiodic = pd.read_excel(f"{path_aperiodic}MCI/Tur_IUEFM_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")

# Directorio PD
df_PD_arg_aperiodic = pd.read_excel(f"{path_aperiodic}PD/ARG_F17_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_chile_aperiodic = pd.read_excel(f"{path_aperiodic}PD/CH_Taknew_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch_f17_aperiodic = pd.read_excel(f"{path_aperiodic}PD/CH_F17_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch_new2_aperiodic = pd.read_excel(f"{path_aperiodic}PD/CH_Tak_new2_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch_new3_aperiodic = pd.read_excel(f"{path_aperiodic}PD/CH_Tak_new3_PD_processed_SourceTransformation_ODQ_metrics.xlsx")

# %%
import pandas as pd

# Ruta principal
path_complex = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Complex/'

# Directorio AD
df_AD_arg_complex = pd.read_excel(f"{path_complex}AD/AR_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_ch_complex = pd.read_excel(f"{path_complex}AD/Ch_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_col_complex = pd.read_excel(f"{path_complex}AD/Col_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_tur_complex = pd.read_excel(f"{path_complex}AD/Tur_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_usp_complex = pd.read_excel(f"{path_complex}AD/USP_processed_SourceTransformation_AD_Complexity_metrics_ODQ.xlsx")

# Directorio CN
df_CN_complex = pd.read_excel(f"{path_complex}CN/complexity_jhos_30.xlsx")

# Directorio FTD
df_FTD_arg_complex = pd.read_excel(f"{path_complex}FTD/ARG_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")
df_FTD_ch_complex = pd.read_excel(f"{path_complex}FTD/CH_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")
df_FTD_col_complex = pd.read_excel(f"{path_complex}FTD/Col_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")

# Directorio MCI
df_MCI_col_complex = pd.read_excel(f"{path_complex}MCI/Col_USCO_processed_SourceTransformation_MCI_ODQ_metrics - copia.xlsx")
df_MCI_tur_complex = pd.read_excel(f"{path_complex}MCI/Tur_IUEFM_processed_SourceTransformation_DCL_ODQ_metrics - copia.xlsx")

# Directorio PD
df_PD_arg_complex = pd.read_excel(f"{path_complex}PD/AR_F17_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch_complex = pd.read_excel(f"{path_complex}PD/CH_PD_processed_SourceTransformation_ODQ_metrics.xlsx")

# %%
import pandas as pd

# Ruta principal
path_freq = 'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/metricas/Freq/'

# Directorio AD
df_AD_arg_freq = pd.read_excel(f"{path_freq}AD/AD_ARG_freq.xlsx")
df_AD_col_freq = pd.read_excel(f"{path_freq}AD/AD_Col_freq.xlsx")
df_AD_bra_freq = pd.read_excel(f"{path_freq}AD/Bra_USP_AD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_AD_ch_freq = pd.read_excel(f"{path_freq}AD/CH_freq.xlsx")
df_AD_tur_freq = pd.read_excel(f"{path_freq}AD/Tur_IUEFM_AD_processed_SourceTransformation_ODQ_metrics.xlsx")

# Directorio CN
df_CN_freq = pd.read_excel(f"{path_freq}CN/frecuency_jhos_.xlsx")

# Directorio FTD
df_FTD_arg_freq = pd.read_excel(f"{path_freq}FTD/ARG_FTD_freq.xlsx")
df_FTD_ch_freq = pd.read_excel(f"{path_freq}FTD/CH_FTD_freq.xlsx")
df_FTD_tak_freq = pd.read_excel(f"{path_freq}FTD/Tak_Col_Bog_processed_SourceTransformation_ODQ_metrics.xlsx")

# Directorio MCI
df_MCI_col_freq = pd.read_excel(f"{path_freq}MCI/Col_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")
df_MCI_tur_freq = pd.read_excel(f"{path_freq}MCI/Tur_IUEFM_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")

# Directorio PD
df_PD_arg_freq = pd.read_excel(f"{path_freq}PD/ARG_F17_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_chile_freq = pd.read_excel(f"{path_freq}PD/Chile_Takeda_new_PD_SourceTransformation_PD_Frecuency_metrics_ODQ_metrics.xlsx")
df_PD_ch1_freq = pd.read_excel(f"{path_freq}PD/CH_F17_Frecuency_metrics_ODQ_metrics.xlsx")
df_PD_ch2_freq = pd.read_excel(f"{path_freq}PD/CH_Tak_new2_PD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_PD_ch3_freq = pd.read_excel(f"{path_freq}PD/CH_Tak_new3_PD_processed_SourceTransformation_ODQ_metrics.xlsx")

# %% [markdown]
# # CN

# %%
# Directorio CN
df_CN_aperiodic = pd.read_excel(f"{path_aperiodic}CN/aperiodic_jhosmary_03.xlsx")
df_CN_complex = pd.read_excel(f"{path_complex}CN/complexity_jhos_30.xlsx")
df_CN_freq = pd.read_excel(f"{path_freq}CN/frecuency_jhos_.xlsx")
print(df_CN_aperiodic.shape, df_CN_complex.shape, df_CN_freq.shape)
# Out:
# (1383, 42) (1383, 20) (1384, 227)

# %%
# Extraemos las listas de identificadores de cada DataFrame
subjects_aperiodic = df_CN_aperiodic['Country_ID']
subjects_complex = df_CN_complex['t']
subjects_freq = df_CN_freq['Country_ID']

# Encontrar la intersección de los tres
common_subjects = set(subjects_aperiodic).intersection(subjects_complex).intersection(subjects_freq)

# Ver cuántos sujetos comunes existen
print(f"Número de sujetos comunes: {len(common_subjects)}")
# Out:
# Número de sujetos comunes: 1382

# %%
df_CN_aperiodic_common = df_CN_aperiodic[df_CN_aperiodic['Country_ID'].isin(common_subjects)]
df_CN_complex_common = df_CN_complex[df_CN_complex['t'].isin(common_subjects)]
df_CN_freq_common = df_CN_freq[df_CN_freq['Country_ID'].isin(common_subjects)]

# Ver las primeras filas de los DataFrames filtrados
print(df_CN_aperiodic_common.head(2))
print(df_CN_complex_common.head(2))
print(df_CN_freq_common.head(2))
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        2.859768         1.767303         2.415282
# 1           1        1.309688         1.667206         1.528242
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.727924         3.081733          2.077333           2.413411
# 1          1.537064         1.376505          2.009045           1.636336
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Country_x      Site_x  \
# 0            1.768170        3.129080  ...       Cuba  CUB_123_2_
# 1            1.460334        1.433874  ...       Cuba  CUB_123_2_
#
#               Country_ID   Age  Sex  Educ  MMSE        ODQ  GINI    Site_x.1
# 0  CUB_123_2_sub-10001    33.0  1.0  19.0  30.0  99.282421  40.7  CUB_123_2_
# 1  CUB_123_2_sub-10004    57.0  2.0  13.0   NaN  99.739738  40.7  CUB_123_2_
#
# [2 rows x 42 columns]
#    Unnamed: 0  SSV_IFG_L  SSV_IFG_R  SSV_TEMP_left  SSV_TEMP_right  \
# ...

# %%
# Renombrar la columna en df_CN_complex para que coincida con los otros DataFrames
df_CN_complex_common.rename(columns={'t': 'Country_ID'}, inplace=True)

# Unir los tres DataFrames usando 'Country_ID'
df_merged_CN = df_CN_aperiodic_common.merge(df_CN_complex_common, on='Country_ID').merge(df_CN_freq_common, on='Country_ID')

# Ver el DataFrame resultante
print(df_merged_CN.head(2))
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        2.859768         1.767303         2.415282
# 1             1        1.309688         1.667206         1.528242
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.727924         3.081733          2.077333           2.413411
# 1          1.537064         1.376505          2.009045           1.636336
#
#    Slope_PARIET_right  Slope_OCC_left  ...  IAF_INS_right  IAF_OCC_left  \
# 0            1.768170        3.129080  ...          8.625      8.833333
# 1            1.460334        1.433874  ...         11.625     11.375000
#
#    IAF_OCC_right   Age  Sex  Educ  MMSE   HDI_y  GINI        ODQ
# 0       8.791667  33.0  1.0  19.0  30.0  0.7578  40.7  99.282421
# 1      11.500000  57.0  2.0  13.0   NaN  0.7578  40.7  99.739738
#
# [2 rows x 287 columns]

# %%
df_merged_CN['ID-unique'] = range(len(df_merged_CN))

# %%
# Guardar el DataFrame combinado en un archivo Excel
df_merged_CN.to_excel('CN_combined.xlsx', index=False)

print("Archivo Excel guardado exitosamente.")
# Out:
# Archivo Excel guardado exitosamente.

# %% [markdown]
# # AD

# %%
# Directorio AD
df_AD_arg_aperiodic = pd.read_excel(f"{path_aperiodic}AD/AR_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_bra_aperiodic = pd.read_excel(f"{path_aperiodic}AD/Bra_USP_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_AD_ch_aperiodic = pd.read_excel(f"{path_aperiodic}AD/CH_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_AD_col_aperiodic = pd.read_excel(f"{path_aperiodic}AD/COL_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_tur_aperiodic = pd.read_excel(f"{path_aperiodic}AD/Tur_IUEFM_AD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")

df_AD_arg_complex = pd.read_excel(f"{path_complex}AD/AR_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_ch_complex = pd.read_excel(f"{path_complex}AD/Ch_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_col_complex = pd.read_excel(f"{path_complex}AD/Col_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_tur_complex = pd.read_excel(f"{path_complex}AD/Tur_AD_SourceTransformation_complex_metrics_ODQ - copia.xlsx")
df_AD_bra_complex = pd.read_excel(f"{path_complex}AD/USP_processed_SourceTransformation_AD_Complexity_metrics_ODQ.xlsx")

df_AD_arg_freq = pd.read_excel(f"{path_freq}AD/AD_ARG_freq.xlsx")
df_AD_col_freq = pd.read_excel(f"{path_freq}AD/AD_Col_freq.xlsx")
df_AD_bra_freq = pd.read_excel(f"{path_freq}AD/Bra_USP_AD_processed_SourceTransformation_ODQ_metrics.xlsx")
df_AD_ch_freq = pd.read_excel(f"{path_freq}AD/CH_freq.xlsx")
df_AD_tur_freq = pd.read_excel(f"{path_freq}AD/Tur_IUEFM_AD_processed_SourceTransformation_ODQ_metrics.xlsx")

print(df_AD_arg_aperiodic.shape, df_AD_bra_aperiodic.shape, df_AD_ch_aperiodic.shape, df_AD_col_aperiodic.shape,df_AD_tur_aperiodic.shape,
     df_AD_arg_complex.shape, df_AD_ch_complex.shape ,df_AD_col_complex.shape,df_AD_tur_complex.shape,df_AD_usp_complex.shape,
     df_AD_arg_freq.shape,df_AD_col_freq.shape,df_AD_bra_freq.shape,df_AD_ch_freq.shape,df_AD_tur_freq.shape)
# Out:
# (29, 42) (76, 42) (62, 42) (47, 42) (96, 42) (32, 21) (64, 22) (47, 22) (96, 22) (76, 21) (32, 231) (47, 231) (76, 231) (63, 231) (96, 231)

# %%
import pandas as pd
import numpy as np

# Extraer el número final de los IDs en ambos DataFrames
df_AD_arg_complex['ID_Number'] = df_AD_arg_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_arg_aperiodic['ID_Number'] = df_AD_arg_aperiodic['Country_ID'].str.extract(r'(\d+)$')
# Crear un diccionario de mapeo del segundo DataFrame
mapping = df_AD_arg_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
# Mapear los valores al primer DataFrame
df_AD_arg_complex['Country_ID_2'] = df_AD_arg_complex['ID_Number'].map(mapping)

# Eliminar la columna auxiliar si no se necesita
#df_AD_arg_complex.drop(columns='ID_Number', inplace=True)


df_AD_ch_complex['ID_Number'] = df_AD_ch_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_ch_aperiodic['ID_Number'] = df_AD_ch_aperiodic['Country_ID'].str.extract(r'(\d+)$')
mapping = df_AD_ch_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
df_AD_ch_complex['Country_ID_2'] = df_AD_ch_complex['ID_Number'].map(mapping)


df_AD_col_complex['ID_Number'] = df_AD_col_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_col_aperiodic['ID_Number'] = df_AD_col_aperiodic['Country_ID'].str.extract(r'(\d+)$')
mapping = df_AD_col_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
df_AD_col_complex['Country_ID_2'] = df_AD_col_complex['ID_Number'].map(mapping)

df_AD_ch_complex['ID_Number'] = df_AD_ch_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_ch_aperiodic['ID_Number'] = df_AD_ch_aperiodic['Country_ID'].str.extract(r'(\d+)$')
mapping = df_AD_ch_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
df_AD_ch_complex['Country_ID_2'] = df_AD_ch_complex['ID_Number'].map(mapping)


df_AD_tur_complex['ID_Number'] = df_AD_tur_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_tur_aperiodic['ID_Number'] = df_AD_tur_aperiodic['Country_ID'].str.extract(r'(\d+)$')
mapping = df_AD_tur_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
df_AD_tur_complex['Country_ID_2'] = df_AD_tur_complex['ID_Number'].map(mapping)

df_AD_bra_complex['ID_Number'] = df_AD_bra_complex['Country_ID'].str.extract(r'(\d+)$')
df_AD_bra_aperiodic['ID_Number'] = df_AD_bra_aperiodic['Country_ID'].str.extract(r'(\d+)$')
mapping = df_AD_bra_aperiodic.set_index('ID_Number')['Country_ID'].to_dict()
df_AD_bra_complex['Country_ID_2'] = df_AD_bra_complex['ID_Number'].map(mapping)


# Ver el resultado
#print(df_AD_arg_complex)

# %%
import pandas as pd

# Concatenamos todos los DataFrames en cada lista
df_AD_aperiodic = pd.concat([df_AD_arg_aperiodic, df_AD_bra_aperiodic, df_AD_ch_aperiodic, df_AD_col_aperiodic, df_AD_tur_aperiodic], ignore_index=True)
df_AD_complex = pd.concat([df_AD_arg_complex, df_AD_bra_complex, df_AD_ch_complex, df_AD_col_complex, df_AD_tur_complex], ignore_index=True)
df_AD_freq = pd.concat([df_AD_arg_freq,  df_AD_bra_freq, df_AD_ch_freq,df_AD_col_freq, df_AD_tur_freq], ignore_index=True)

# %%
df_AD_aperiodic['Country_ID_2']=df_AD_aperiodic['Country_ID']
df_AD_freq['Country_ID_2']=df_AD_freq['Country_ID']

# %%
# Extraemos las listas de identificadores de cada DataFrame
subjects_aperiodic = df_AD_aperiodic['Country_ID_2']
subjects_complex = df_AD_complex['Country_ID_2']
subjects_freq = df_AD_freq['Country_ID']

# %%
# Encontrar la intersección de los tres
common_subjects = set(subjects_aperiodic).intersection(subjects_complex).intersection(subjects_freq)

# Ver cuántos sujetos comunes existen
print(f"Número de sujetos comunes: {len(common_subjects)}")
# Out:
# Número de sujetos comunes: 306

# %%
df_AD_aperiodic_common = df_AD_aperiodic[df_AD_aperiodic['Country_ID_2'].isin(common_subjects)]
df_AD_complex_common = df_AD_complex[df_AD_complex['Country_ID_2'].isin(common_subjects)]
df_AD_freq_common = df_AD_freq[df_AD_freq['Country_ID_2'].isin(common_subjects)]

# Ver las primeras filas de los DataFrames filtrados
print(df_AD_aperiodic_common.head(2))
print(df_AD_complex_common.head(2))
print(df_AD_freq_common.head(2))
# Out:
#   Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 4          4        1.657409         1.791276         3.266917
# 5          5        1.948224         2.565999         1.030199
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 4          3.692153         2.078647          1.445966           1.445989
# 5          1.142947         1.527375          1.753363           1.041908
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Educ   MMSE        ODQ    Country  \
# 4            2.056778        1.040193  ...     6  23.74  99.524933  Argentina
# 5            1.093190        1.087747  ...     6  22.62  99.673196  Argentina
#
#    Eurolad_code  GINI  Group         ID  ID_Number       Country_ID_2
# 4       ARG_F14  41.8     AD  sub-10007      10007  ARG_F14_sub-10007
# 5       ARG_F14  41.8     AD  sub-10008      10008  ARG_F14_sub-10008
#
# [2 rows x 44 columns]
#    Unnamed: 0  SSV_IFG_L  SSV_IFG_R  SSV_TEMP_left  SSV_TEMP_right  \
# ...

# %%
# Renombrar la columna en df_CN_complex para que coincida con los otros DataFrames
#df_AD_complex_common.rename(columns={'t': 'Country_ID'}, inplace=True)

# Unir los tres DataFrames usando 'Country_ID'
df_merged_AD = df_AD_aperiodic_common.merge(df_AD_complex_common, on='Country_ID_2').merge(df_AD_freq_common, on='Country_ID_2')

# Ver el DataFrame resultante
print(df_merged_AD.head(2))
# Out:
#   Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0            4        1.657409         1.791276         3.266917
# 1            5        1.948224         2.565999         1.030199
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          3.692153         2.078647          1.445966           1.445989
# 1          1.142947         1.527375          1.753363           1.041908
#
#    Slope_PARIET_right  Slope_OCC_left  ...   Age  Educ   MMSE        ODQ  \
# 0            2.056778        1.040193  ...  71.0   6.0  23.74  99.524933
# 1            1.093190        1.087747  ...  80.0   6.0  22.62  99.673196
#
#      Country  Eurolad_code  GINI  Group         ID  Diagnosis_y
# 0  Argentina       ARG_F14  41.8     AD  sub-10007            1
# 1  Argentina       ARG_F14  41.8     AD  sub-10008            1
#
# [2 rows x 298 columns]

# %%
df_merged_AD['ID-unique'] = range(len(df_merged_AD))

# %%
# Guardar el DataFrame combinado en un archivo Excel
df_merged_AD.to_excel('AD_combined.xlsx', index=False)

print("Archivo Excel guardado exitosamente.")
# Out:
# Archivo Excel guardado exitosamente.

# %% [markdown]
# # FTD

# %%
# Directorio FTD
df_FTD_arg_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/ARG_FTD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_FTD_ch_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/CH_FTD_processed_SourceTransformation_ODQ_metrics - copia.xlsx")
df_FTD_col_aperiodic = pd.read_excel(f"{path_aperiodic}FTD/Col_processed_SourceTransformation_ODQ_metrics - copia.xlsx")

# Directorio FTD
df_FTD_arg_complex = pd.read_excel(f"{path_complex}FTD/ARG_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")
df_FTD_ch_complex = pd.read_excel(f"{path_complex}FTD/CH_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")
df_FTD_col_complex = pd.read_excel(f"{path_complex}FTD/Col_processed_SourceTransformation_FTD_ODQ_metrics - copia.xlsx")

df_FTD_arg_freq = pd.read_excel(f"{path_freq}FTD/ARG_FTD_freq.xlsx")
df_FTD_ch_freq = pd.read_excel(f"{path_freq}FTD/CH_FTD_freq.xlsx")
df_FTD_col_freq = pd.read_excel(f"{path_freq}FTD/Tak_Col_Bog_processed_SourceTransformation_ODQ_metrics.xlsx")


print(df_FTD_arg_aperiodic.shape, df_FTD_ch_aperiodic.shape, df_FTD_col_aperiodic.shape,
     df_FTD_arg_complex.shape, df_FTD_ch_complex.shape ,df_FTD_col_complex.shape,
     df_FTD_arg_freq.shape,df_FTD_ch_freq.shape,df_FTD_col_freq.shape)
# Out:
# (29, 39) (24, 39) (12, 40) (31, 21) (24, 21) (12, 21) (32, 231) (24, 231) (6, 231)

# %%
# Seleccionar las columnas relevantes para la comparación
columns_to_match = ['Age', 'Sex', 'Educ', 'MMSE', 'ODQ', 'GINI']

# Realizar un merge con las columnas clave para encontrar coincidencias
merged_df = df_FTD_arg_aperiodic.merge(
    df_FTD_arg_complex[['ID'] + columns_to_match], 
    on=columns_to_match, 
    how='left'
)

# Verificar el resultado
df_FTD_arg_aperiodic['ID'] = merged_df['ID']

# Imprimir los primeros registros para confirmar
print(df_FTD_arg_aperiodic.head())
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        1.155978         1.660777         2.298852
# 1           1        1.479669         1.437262         1.396243
# 2           2        1.376364         0.875103         1.092503
# 3           3        0.636676         0.784739         0.660823
# 4           4        2.089692         1.522240         3.517030
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.571176         1.868578          2.245640           2.193582
# 1          1.469099         1.514617          1.306546           1.439433
# 2          1.423893         1.297217          0.857772           0.883458
# 3          0.687036         0.556988          0.735036           0.629617
# 4          4.265048         2.231430          1.181279           2.116937
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Offset_OCC_right   Age  Sex  Educ  \
# ...

# %%
# Seleccionar las columnas relevantes para la comparación
columns_to_match = ['Age', 'Sex', 'Educ', 'MMSE', 'ODQ', 'GINI']

# Realizar un merge con las columnas clave para encontrar coincidencias
merged_df = df_FTD_ch_aperiodic.merge(
    df_FTD_ch_complex[['ID'] + columns_to_match], 
    on=columns_to_match, 
    how='left'
)

# Verificar el resultado
df_FTD_ch_aperiodic['ID'] = merged_df['ID']

# Imprimir los primeros registros para confirmar
print(df_FTD_ch_aperiodic.head())
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        1.152444         1.451740         1.708557
# 1           1        1.429064         1.330094         1.921705
# 2           2        2.107656         3.100740         4.347946
# 3           3        1.691928         2.150653         2.639260
# 4           4        1.819893         1.193556         1.802277
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.004557         1.257764          1.227816           1.797962
# 1          2.128663         1.139679          0.789181           2.338547
# 2          4.808743         2.117354          3.343650           3.770900
# 3          2.585239         1.858526          2.121278           2.458118
# 4          1.945397         1.299366          1.142186           2.042477
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Offset_OCC_right  Age  Sex  Educ  \
# ...

# %%
# Eliminar la columna 'ID'
df_FTD_col_aperiodic = df_FTD_col_aperiodic.drop(columns=['ID'])

# Confirmar que la columna fue eliminada
print(df_FTD_col_aperiodic.head())
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        0.424469         0.288465         0.607284
# 1           1        1.140681         1.369872         2.348509
# 2           2        2.524440         2.846771         3.709630
# 3           3        0.578102         0.593318         2.021242
# 4           4        1.302915         0.779208         2.254821
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          0.695146         0.196421          0.196778           0.513886
# 1          2.509321         1.197316          1.081712           2.385420
# 2          3.695838         2.604534          2.676552           3.634983
# 3          2.025784         0.680070          0.620585           1.392379
# 4          2.243423         0.968474          0.346802           1.644460
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Offset_OCC_left  Offset_OCC_right  \
# ...

# %%
# Seleccionar las columnas relevantes para la comparación
columns_to_match = ['Age', 'Sex', 'Educ',  'ODQ']

# Realizar un merge con las columnas clave para encontrar coincidencias
merged_df = df_FTD_col_aperiodic.merge(
    df_FTD_col_complex[['ID'] + columns_to_match], 
    on=columns_to_match, 
    how='left'
)

# Verificar el resultado
df_FTD_col_aperiodic['ID'] = merged_df['ID']

# Imprimir los primeros registros para confirmar
print(df_FTD_col_aperiodic.head())
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        0.424469         0.288465         0.607284
# 1           1        1.140681         1.369872         2.348509
# 2           2        2.524440         2.846771         3.709630
# 3           3        0.578102         0.593318         2.021242
# 4           4        1.302915         0.779208         2.254821
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          0.695146         0.196421          0.196778           0.513886
# 1          2.509321         1.197316          1.081712           2.385420
# 2          3.695838         2.604534          2.676552           3.634983
# 3          2.025784         0.680070          0.620585           1.392379
# 4          2.243423         0.968474          0.346802           1.644460
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Offset_OCC_right  Age  Sex  Educ  \
# ...

# %%
import pandas as pd
import numpy as np

# Extraer el número final de los IDs en ambos DataFrames
df_FTD_arg_complex['ID_Number'] = df_FTD_arg_complex['ID'].str.extract(r'(\d+)$')
df_FTD_arg_aperiodic['ID_Number'] = df_FTD_arg_aperiodic['ID'].str.extract(r'(\d+)$')
# Crear un diccionario de mapeo del segundo DataFrame
mapping = df_FTD_arg_aperiodic.set_index('ID_Number')['ID'].to_dict()
# Mapear los valores al primer DataFrame
df_FTD_arg_complex['Country_ID_2'] = df_FTD_arg_complex['ID_Number'].map(mapping)

# Eliminar la columna auxiliar si no se necesita
#df_AD_arg_complex.drop(columns='ID_Number', inplace=True)


df_FTD_ch_complex['ID_Number'] = df_FTD_ch_complex['ID'].str.extract(r'(\d+)$')
df_FTD_ch_aperiodic['ID_Number'] = df_FTD_ch_aperiodic['ID'].str.extract(r'(\d+)$')
mapping = df_FTD_ch_aperiodic.set_index('ID_Number')['ID'].to_dict()
df_FTD_ch_complex['Country_ID_2'] = df_FTD_ch_complex['ID_Number'].map(mapping)


df_FTD_col_complex['ID_Number'] = df_FTD_col_complex['ID'].str.extract(r'(\d+)$')
df_FTD_col_aperiodic['ID_Number'] = df_FTD_col_aperiodic['ID'].str.extract(r'(\d+)$')
mapping = df_FTD_col_aperiodic.set_index('ID_Number')['ID'].to_dict()
df_FTD_col_complex['Country_ID_2'] = df_FTD_col_complex['ID_Number'].map(mapping)

# %%
import pandas as pd

# Concatenamos todos los DataFrames en cada lista
df_FTD_aperiodic = pd.concat([df_FTD_arg_aperiodic,  df_FTD_ch_aperiodic, df_FTD_col_aperiodic], ignore_index=True)
df_FTD_complex = pd.concat([df_FTD_arg_complex,  df_FTD_ch_complex, df_FTD_col_complex], ignore_index=True)
df_FTD_freq = pd.concat([df_FTD_arg_freq,   df_FTD_ch_freq, df_FTD_col_freq], ignore_index=True)

# %%
df_FTD_aperiodic['Country_ID_2']=df_AD_aperiodic['ID']
df_FTD_freq['Country_ID_2']=df_AD_freq['ID']

# %%
# Extraemos las listas de identificadores de cada DataFrame
subjects_aperiodic = df_FTD_aperiodic['Country_ID_2']
subjects_complex = df_FTD_complex['Country_ID_2']
subjects_freq = df_FTD_freq['Country_ID_2']

# %%
# Encontrar la intersección de los tres
common_subjects = set(subjects_aperiodic).intersection(subjects_complex).intersection(subjects_freq)

# Ver cuántos sujetos comunes existen
print(f"Número de sujetos comunes: {len(common_subjects)}")
# Out:
# Número de sujetos comunes: 53

# %%
df_FTD_aperiodic_common = df_FTD_aperiodic[df_FTD_aperiodic['Country_ID_2'].isin(common_subjects)]
df_FTD_complex_common = df_FTD_complex[df_FTD_complex['Country_ID_2'].isin(common_subjects)]
df_FTD_freq_common = df_FTD_freq[df_FTD_freq['Country_ID_2'].isin(common_subjects)]

# Ver las primeras filas de los DataFrames filtrados
print(df_FTD_aperiodic_common.head(2))
print(df_FTD_complex_common.head(2))
print(df_FTD_freq_common.head(2))
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        1.155978         1.660777         2.298852
# 1           1        1.479669         1.437262         1.396243
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.571176         1.868578          2.245640           2.193582
# 1          1.469099         1.514617          1.306546           1.439433
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Sex  Educ   MMSE        ODQ  GINI  \
# 0            2.285243        0.895963  ...    2  16.0  26.94  99.487845  41.4
# 1            1.493425        1.684383  ...    2   NaN  13.34  99.278556  41.4
#
#    Diagnosis  Region         ID  ID_Number  Country_ID_2
# 0        FTD     ARG  sub-10001      10001     sub-10001
# 1        FTD     ARG  sub-10002      10002     sub-10002
#
# [2 rows x 42 columns]
#    Unnamed: 0  SSV_IFG_L  SSV_IFG_R  SSV_TEMP_left  SSV_TEMP_right  \
# ...

# %%
# Renombrar la columna en df_CN_complex para que coincida con los otros DataFrames
#df_AD_complex_common.rename(columns={'t': 'Country_ID'}, inplace=True)

# Unir los tres DataFrames usando 'Country_ID'
df_merged_FTD = df_FTD_aperiodic_common.merge(df_FTD_complex_common, on='Country_ID_2').merge(df_FTD_freq_common, on='Country_ID_2')

# Ver el DataFrame resultante
print(df_merged_FTD.head(2))
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        1.155978         1.660777         2.298852
# 1             1        1.479669         1.437262         1.396243
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.571176         1.868578          2.245640           2.193582
# 1          1.469099         1.514617          1.306546           1.439433
#
#    Slope_PARIET_right  Slope_OCC_left  ...   Age  Educ   MMSE        ODQ  \
# 0            2.285243        0.895963  ...  78.0  16.0  26.94  99.487845
# 1            1.493425        1.684383  ...   NaN   NaN  13.34  99.278556
#
#    Country_y  Eurolad_code_y  GINI  Group_y         ID  Diagnosis_y
# 0  Argentina         ARG_F14  41.4      FTD  sub-10001            1
# 1  Argentina         ARG_F14  41.4      FTD  sub-10002            1
#
# [2 rows x 295 columns]

# %%
df_merged_FTD['ID-unique'] = range(len(df_merged_FTD))

# %%
# Guardar el DataFrame combinado en un archivo Excel
df_merged_FTD.to_excel('FTD_combined.xlsx', index=False)

print("Archivo Excel guardado exitosamente.")
# Out:
# Archivo Excel guardado exitosamente.

# %% [markdown]
# # MCI

# %%
# Directorio MCI
df_MCI_col_aperiodic = pd.read_excel(f"{path_aperiodic}MCI/Col_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")
df_MCI_tur_aperiodic = pd.read_excel(f"{path_aperiodic}MCI/Tur_IUEFM_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")

df_MCI_col_complex = pd.read_excel(f"{path_complex}MCI/Col_USCO_processed_SourceTransformation_MCI_ODQ_metrics - copia.xlsx")
df_MCI_tur_complex = pd.read_excel(f"{path_complex}MCI/Tur_IUEFM_processed_SourceTransformation_DCL_ODQ_metrics - copia.xlsx")

df_MCI_col_freq = pd.read_excel(f"{path_freq}MCI/Col_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")
df_MCI_tur_freq = pd.read_excel(f"{path_freq}MCI/Tur_IUEFM_MCI_processed_SourceTransformation_ODQ_metrics.xlsx")

print(df_MCI_col_aperiodic.shape, df_MCI_tur_aperiodic.shape,
     df_MCI_col_complex.shape, df_MCI_tur_complex.shape ,
     df_MCI_col_freq.shape,df_MCI_tur_freq.shape)
# Out:
# (133, 42) (95, 42) (133, 21) (95, 21) (133, 231) (95, 231)

# %%
df_MCI_col_aperiodic

# %%
df_MCI_col_complex

# %%
df_MCI_col_freq

# %%
import pandas as pd

# Concatenamos todos los DataFrames en cada lista
df_MCI_aperiodic = pd.concat([df_MCI_col_aperiodic, df_MCI_tur_aperiodic], ignore_index=True)
df_MCI_complex = pd.concat([df_MCI_col_complex, df_MCI_tur_complex], ignore_index=True)
df_MCI_freq = pd.concat([df_MCI_col_freq,  df_MCI_tur_freq], ignore_index=True)

# %%
df_MCI_aperiodic['Group']='MCI'

# %%
df_MCI_freq['Group']='MCI'

# %%
df_MCI_aperiodic
# Out:
#      Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        1.337510         2.251347         1.233506
# 1             1        0.915137         0.630239         0.791544
# 2             2        0.946000         0.888339         1.427817
# 3             3        1.517780         1.564565         2.433183
# 4             4        0.543274         0.362486         0.775562
# ..          ...             ...              ...              ...
# 223          90        0.928654         1.856354         2.726174
# 224          91        0.803074         1.787699         1.607293
# 225          92        1.460791         1.294854         1.542707
# 226          93        1.997895         1.862788         3.159962
# 227          94        1.436777         1.098632         2.590858
#
#      Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0            1.504801         1.379055          1.559732           1.618886
# ...

# %%
# Extraemos las listas de identificadores de cada DataFrame
subjects_aperiodic = df_MCI_aperiodic['ID']
subjects_complex = df_MCI_complex['ID']
subjects_freq = df_MCI_freq['ID']

# %%
# Encontrar la intersección de los tres
common_subjects = set(subjects_aperiodic).intersection(subjects_complex).intersection(subjects_freq)

# Ver cuántos sujetos comunes existen
print(f"Número de sujetos comunes: {len(common_subjects)}")
# Out:
# Número de sujetos comunes: 186

# %%
df_MCI_aperiodic_common = df_MCI_aperiodic[df_MCI_aperiodic['ID'].isin(common_subjects)]
df_MCI_complex_common = df_MCI_complex[df_MCI_complex['ID'].isin(common_subjects)]
df_MCI_freq_common = df_MCI_freq[df_MCI_freq['ID'].isin(common_subjects)]

# Ver las primeras filas de los DataFrames filtrados
print(df_MCI_aperiodic_common.head(2))
print(df_MCI_complex_common.head(2))
print(df_MCI_freq_common.head(2))
# Out:
#    Unnamed: 0  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0           0        1.337510         2.251347         1.233506
# 1           1        0.915137         0.630239         0.791544
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          1.504801         1.379055          1.559732           1.618886
# 1          1.057216         0.682451          0.459493           1.223334
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Sex  Age  Educ  MMSE        ODQ  \
# 0            1.483839        1.327416  ...    2   59    12  27.0  99.469512
# 1            1.238947        0.782806  ...    1   65    16  22.0  98.257927
#
#     Country  Eurolad_code  GINI  Group         ID
# 0  Colombia      Col_USCO  54.8    MCI  sub-10003
# 1  Colombia      Col_USCO  54.8    MCI  sub-10004
#
# [2 rows x 42 columns]
#    Unnamed: 0  SSV_IFG_L  SSV_IFG_R  SSV_TEMP_left  SSV_TEMP_right  \
# 0           0   0.046506   0.040475       0.041438        0.034626
# ...

# %%
# Renombrar la columna en df_CN_complex para que coincida con los otros DataFrames
#df_AD_complex_common.rename(columns={'t': 'Country_ID'}, inplace=True)

# Unir los tres DataFrames usando 'Country_ID'
df_merged_MCI = df_MCI_aperiodic_common.merge(df_MCI_complex_common, on='ID').merge(df_MCI_freq_common, on='ID')

# Ver el DataFrame resultante
print(df_merged_MCI.head(2))
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0         1.33751         2.251347         1.233506
# 1             0         1.33751         2.251347         1.233506
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          1.504801         1.379055          1.559732           1.618886
# 1          1.504801         1.379055          1.559732           1.618886
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Sex  Age  Educ  MMSE        ODQ  \
# 0            1.483839        1.327416  ...    2   59  12.0  27.0  99.469512
# 1            1.483839        1.327416  ...    1   59   5.0  23.0  99.723011
#
#     Country  Eurolad_code       GINI  Group  Diagnosis
# 0  Colombia      Col_USCO  54.800000    MCI          1
# 1   Turquia     Tur_IUEFM  43.329412    MCI          1
#
# [2 rows x 292 columns]

# %%
df_merged_MCI['ID-unique'] = range(len(df_merged_MCI))

# %%
# Guardar el DataFrame combinado en un archivo Excel
df_merged_MCI.to_excel('MCI_combined.xlsx', index=False)

print("Archivo Excel guardado exitosamente.")
# Out:
# Archivo Excel guardado exitosamente.

# %% [markdown]
# # Revision data

# %%
path_metric = 'C:/Users/felipe/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Multiple_Brain_Age_Clocks/pre_data'

# %%
df_CN_ = pd.read_excel(f"{path_metric}/CN_combined.xlsx")
df_AD_ = pd.read_excel(f"{path_metric}/AD_combined.xlsx")
df_FTD_ = pd.read_excel(f"{path_metric}/FTD_combined.xlsx")
df_MCI_ = pd.read_excel(f"{path_metric}/MCI_combined.xlsx")

# %%
df_CN_.head()
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        2.859768         1.767303         2.415282
# 1             1        1.309688         1.667206         1.528242
# 2             2        1.257444         0.840704         1.330353
# 3             3        1.682139         1.355977         1.080644
# 4             4        0.866675         0.366260         0.455986
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.727924         3.081733          2.077333           2.413411
# 1          1.537064         1.376505          2.009045           1.636336
# 2          1.294367         1.342255          0.898285           1.438093
# 3          0.955786         1.684404          1.144267           1.448098
# 4          0.425098         0.870994          0.353314           0.830158
#
#    Slope_PARIET_right  Slope_OCC_left  ...  IAF_OCC_left  IAF_OCC_right   Age  \
# ...

# %%
df_AD_.head()
# Out:
#   Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0            4        1.657409         1.791276         3.266917
# 1            5        1.948224         2.565999         1.030199
# 2            6        2.351906         1.582038         1.184849
# 3            7        0.973230         0.637438         2.346555
# 4            8        1.341195         2.123403         2.265030
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          3.692153         2.078647          1.445966           1.445989
# 1          1.142947         1.527375          1.753363           1.041908
# 2          1.125776         1.712991          1.561278           1.187456
# 3          2.326625         1.785846          0.584286           2.508437
# 4          2.556667         1.132086          1.787175           1.488300
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Educ   MMSE        ODQ    Country  \
# ...

# %%
df_FTD_.head()
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        1.155978         1.660777         2.298852
# 1             1        1.479669         1.437262         1.396243
# 2             1        1.479669         1.437262         1.396243
# 3             1        1.479669         1.437262         1.396243
# 4             1        1.479669         1.437262         1.396243
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          2.571176         1.868578          2.245640           2.193582
# 1          1.469099         1.514617          1.306546           1.439433
# 2          1.469099         1.514617          1.306546           1.439433
# 3          1.469099         1.514617          1.306546           1.439433
# 4          1.469099         1.514617          1.306546           1.439433
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Educ   MMSE        ODQ  Country_y  \
# ...

# %%
df_MCI_.head()
# Out:
#    Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0             0        1.337510         2.251347         1.233506
# 1             0        1.337510         2.251347         1.233506
# 2             0        1.337510         2.251347         1.233506
# 3             0        1.337510         2.251347         1.233506
# 4             1        0.915137         0.630239         0.791544
#
#    Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0          1.504801         1.379055          1.559732           1.618886
# 1          1.504801         1.379055          1.559732           1.618886
# 2          1.504801         1.379055          1.559732           1.618886
# 3          1.504801         1.379055          1.559732           1.618886
# 4          1.057216         0.682451          0.459493           1.223334
#
#    Slope_PARIET_right  Slope_OCC_left  ...  Age  Educ  MMSE        ODQ  \
# ...

# %%
df_CN_.iloc[:,1 :31]
# Out:
#       Slope_HPC_left  Slope_HPC_right  Slope_CING_left  Slope_CING_right  \
# 0           2.859768         1.767303         2.415282          2.727924
# 1           1.309688         1.667206         1.528242          1.537064
# 2           1.257444         0.840704         1.330353          1.294367
# 3           1.682139         1.355977         1.080644          0.955786
# 4           0.866675         0.366260         0.455986          0.425098
# ...              ...              ...              ...               ...
# 1384        0.860623         0.726887         0.984260          0.996106
# 1385        3.240214         2.554994         4.075704          4.236230
# 1386        2.732930         2.810929         2.014831          2.376631
# 1387        3.003057         2.705750         3.486568          3.536880
# 1388        0.801384         1.119070         1.473746          1.680619
#
#       Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# ...

# %%
df_AD_.iloc[:, :31]
# Out:
#     Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0              4        1.657409         1.791276         3.266917
# 1              5        1.948224         2.565999         1.030199
# 2              6        2.351906         1.582038         1.184849
# 3              7        0.973230         0.637438         2.346555
# 4              8        1.341195         2.123403         2.265030
# ..           ...             ...              ...              ...
# 305           91        0.759163         0.279734         1.388044
# 306           92        1.792184         1.092699         3.419817
# 307           93        0.705395         0.598054         1.673441
# 308           94        1.340865         2.388338         2.063366
# 309           95        1.404514         0.893827         2.047032
#
#      Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# 0            3.692153         2.078647          1.445966           1.445989
# ...

# %%
df_FTD_.iloc[:, :31]
# Out:
#      Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0               0        1.155978         1.660777         2.298852
# 1               1        1.479669         1.437262         1.396243
# 2               1        1.479669         1.437262         1.396243
# 3               1        1.479669         1.437262         1.396243
# 4               1        1.479669         1.437262         1.396243
# ..            ...             ...              ...              ...
# 96              1        0.000178         0.000183         0.341212
# 97              2        1.712491         1.239579         2.034738
# 98              2        1.712491         1.239579         2.034738
# 99              3        1.087576         0.547175         1.716540
# 100             3        1.087576         0.547175         1.716540
#
#      Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# ...

# %%
df_MCI_.iloc[:, :31]
# Out:
#      Unnamed: 0_x  Slope_HPC_left  Slope_HPC_right  Slope_CING_left  \
# 0               0        1.337510         2.251347         1.233506
# 1               0        1.337510         2.251347         1.233506
# 2               0        1.337510         2.251347         1.233506
# 3               0        1.337510         2.251347         1.233506
# 4               1        0.915137         0.630239         0.791544
# ..            ...             ...              ...              ...
# 475            93        1.997895         1.862788         3.159962
# 476            93        1.997895         1.862788         3.159962
# 477            93        1.997895         1.862788         3.159962
# 478            93        1.997895         1.862788         3.159962
# 479            94        1.436777         1.098632         2.590858
#
#      Slope_CING_right  Slope_TEMP_left  Slope_TEMP_right  Slope_PARIET_left  \
# ...

# %%
df_CN_.iloc[:, 43:52]
# Out:
#       SSV_IFG_L  SSV_IFG_R  SSV_TEMP_left  SSV_TEMP_right  SSV_OCC_left  \
# 0      0.006332   0.005878       0.002696        0.007597      0.001630
# 1      0.004393   0.006609       0.005131        0.002860      0.008439
# 2      0.004991   0.012247       0.004234        0.008351      0.004922
# 3      0.009637   0.010634       0.002398        0.005989      0.006487
# 4      0.047744   0.044420       0.021100        0.041289      0.033726
# ...         ...        ...            ...             ...           ...
# 1384   0.039185   0.057890       0.028184        0.045887      0.023076
# 1385   0.015117   0.029721       0.009227        0.020449      0.005755
# 1386   0.020988   0.022166       0.017896        0.015321      0.017710
# 1387   0.008930   0.008111       0.056805        0.016624      0.108049
# 1388   0.049871   0.047787       0.049337        0.040588      0.028305
#
#       SSV_OCC_right  WMEAN_ALL    PE_ALL    FD_ALL
# 0          0.006095  -0.686534  1.115442  0.858276
# ...

# %%
df_CN_.iloc[:, 62:280]
# Out:
#       Delta_canon_EPP_ORB_left  Delta_canon_EPP_ORB_right  \
# 0                     0.059161                   0.070466
# 1                     0.054096                   0.047097
# 2                     0.059660                   0.051740
# 3                     0.058654                   0.056826
# 4                     0.043061                   0.042042
# ...                        ...                        ...
# 1384                  0.035464                   0.035469
# 1385                  0.054815                   0.048826
# 1386                  0.044759                   0.052309
# 1387                  0.059905                   0.064894
# 1388                  0.032594                   0.038136
#
#       Delta_canon_EPP_IFG_left  Delta_canon_EPP_IFG_right  \
# 0                     0.051849                   0.049289
# 1                     0.056917                   0.044670
# 2                     0.061596                   0.052308
# ...

# %%
metrics_freq = df_CN_.iloc[:, 62:280].columns.tolist()
metrics_aperiodic = df_CN_.iloc[:, 1:31].columns.tolist()
metrics_complex = df_CN_.iloc[:, 43:52].columns.tolist()

# %%
X_CN = df_CN_[metrics_freq]
X_AD = df_AD_[metrics_freq]
X_FTD = df_FTD_[metrics_freq]
X_MCI = df_MCI_[metrics_freq]

# %%
X_CN = df_CN_[metrics_aperiodic]
X_AD = df_AD_[metrics_aperiodic]
X_FTD = df_FTD_[metrics_aperiodic]
X_MCI = df_MCI_[metrics_aperiodic]

# %%
X_CN = df_CN_[metrics_complex]
X_AD = df_AD_[metrics_complex]
X_FTD = df_FTD_[metrics_complex]
X_MCI = df_MCI_[metrics_complex]
